# %%
import pandas as pd

# %%
# curve is called as sigmoid cure
#formula = 1/1+e^-z
#0.5 is threshold value

# %%
df=pd.read_csv('Downloads/iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# selecting only 2 categories

# %%
df1=df[(df['Species']=='Iris-setosa')|(df['Species']=='Iris-versicolor')]

# %%
df1['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Name: count, dtype: int64

# %%
df1.shape
# Out:
# (100, 6)

# %%
df1.index=range(0,100)

# %% [markdown]
# # Convert output feature into numberic datatype

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df1['Species']=pd.DataFrame(le.fit_transform(df1['Species']))
# Out:
# C:\Users\waghm\AppData\Local\Temp\ipykernel_20660\2753176633.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Species']=pd.DataFrame(le.fit_transform(df1['Species']))

# %%
df1['Species'].value_counts()
# Out:
# Species
# 0    50
# 1    50
# Name: count, dtype: int64

# %%
df1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %%
df1
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0     1            5.1           3.5            1.4           0.2        0
# 1     2            4.9           3.0            1.4           0.2        0
# 2     3            4.7           3.2            1.3           0.2        0
# 3     4            4.6           3.1            1.5           0.2        0
# 4     5            5.0           3.6            1.4           0.2        0
# ..  ...            ...           ...            ...           ...      ...
# 95   96            5.7           3.0            4.2           1.2        1
# 96   97            5.7           2.9            4.2           1.3        1
# 97   98            6.2           2.9            4.3           1.3        1
# 98   99            5.1           2.5            3.0           1.1        1
# 99  100            5.7           2.8            4.1           1.3        1
#
# [100 rows x 6 columns]

# %%
X=df1.drop(labels='Species',axis=1)

# %%
Y=df1[['Species']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
X=pd.DataFrame(ss.fit_transform(X),columns=X.columns)

# %%
X
# Out:
#           Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0  -1.714816      -0.581066      0.857135      -1.014360     -1.038248
# 1  -1.680173      -0.894309     -0.198450      -1.014360     -1.038248
# 2  -1.645531      -1.207552      0.223784      -1.083741     -1.038248
# 3  -1.610888      -1.364174      0.012667      -0.944978     -1.038248
# 4  -1.576245      -0.737687      1.068253      -1.014360     -1.038248
# ..       ...            ...           ...            ...           ...
# 95  1.576245       0.358663     -0.198450       0.928326      0.736535
# 96  1.610888       0.358663     -0.409567       0.928326      0.914013
# 97  1.645531       1.141771     -0.409567       0.997708      0.914013
# 98  1.680173      -0.581066     -1.254036       0.095747      0.559057
# 99  1.714816       0.358663     -0.620684       0.858945      0.914013
#
# [100 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=21)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
model=lr.fit(xtrain,ytrain)
# Out:
# C:\Users\waghm\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
tr_pred=model.predict(xtrain)

# %%
ts_pred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
tr_score=accuracy_score(ytrain,tr_pred)

# %%
ts_score=accuracy_score(ytest,ts_pred)

# %%
print(tr_score)
# Out:
# 1.0

# %%
print(ts_score)
# Out:
# 1.0

# %%
met=confusion_matrix(ytrain,tr_pred)

# %%
met
# Out:
# array([[38,  0],
#        [ 0, 42]], dtype=int64)

# %%
model.predict_proba(xtrain)
# Out:
# array([[0.99205615, 0.00794385],
#        [0.98877607, 0.01122393],
#        [0.99230089, 0.00769911],
#        [0.99112966, 0.00887034],
#        [0.98815553, 0.01184447],
#        [0.98171859, 0.01828141],
#        [0.96553102, 0.03446898],
#        [0.94885988, 0.05114012],
#        [0.00871726, 0.99128274],
#        [0.97362438, 0.02637562],
#        [0.98733269, 0.01266731],
#        [0.0089411 , 0.9910589 ],
#        [0.03763928, 0.96236072],
#        [0.00919374, 0.99080626],
#        [0.99350684, 0.00649316],
#        [0.03279691, 0.96720309],
#        [0.00858333, 0.99141667],
#        [0.00850585, 0.99149415],
#        [0.97531981, 0.02468019],
#        [0.9844031 , 0.0155969 ],
#        [0.02433028, 0.97566972],
#        [0.97457432, 0.02542568],
#        [0.99044508, 0.00955492],
#        [0.01402316, 0.98597684],
#        [0.99199026, 0.00800974],
#        [0.99413811, 0.00586189],
#        [0.02565757, 0.97434243],
#        [0.00542617, 0.99457383],
# ...

# %%
# X>> price,enginesize,horsepower,type.
#Y>> AirBags('drives only'and 'driver & passenger')

# %%
df=pd.read_csv('Downloads/Cars93.csv')

# %%
df
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...

# %%
df.isna().sum()
# Out:
# id                     0
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags               37
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df.isna().sum().plot(kind='bar')
# Out:
# <Axes: >

# %%
# filling null values
for i in df.columns:
    if df[i].dtypes==object:
        df[i]=df[i].fillna(df[i].mode()[0])
    else:
        df[i]=df[i].fillna(df[i].mean())

# %%
df.isna().sum()
# Out:
# id                    0
# Manufacturer          0
# Model                 0
# Type                  0
# Min.Price             0
# Price                 0
# Max.Price             0
# MPG.city              0
# MPG.highway           0
# AirBags               0
# DriveTrain            0
# Cylinders             0
# EngineSize            0
# Horsepower            0
# RPM                   0
# Rev.per.mile          0
# Man.trans.avail       0
# Fuel.tank.capacity    0
# Passengers            0
# Length                0
# Wheelbase             0
# Width                 0
# Turn.circle           0
# Rear.seat.room        0
# Luggage.room          0
# Weight                0
# Origin                0
# Make                  0
# dtype: int64

# %%
X=df.drop(labels=['Price','EngineSize','Horsepower','Type'],axis=1)
Y=df[['AirBags']]

# %% [markdown]
# # separate categorical and continues features from input features

# %%
cat=[]
con=[]
for i in X.columns:
    if X[i].dtypes==object:
        cat.append(i)
    else:
        con.append(i)

# %%
Xcat=X[cat]
Xcon=X[con]

# %%
X
# Out:
#     id Manufacturer    Model  Min.Price  Max.Price  MPG.city  MPG.highway  \
# 0    1        Acura  Integra       12.9       18.8        25           31
# 1    2        Acura   Legend       29.2       38.7        18           25
# 2    3         Audi       90       25.9       32.3        20           26
# 3    4         Audi      100       30.8       44.6        19           26
# 4    5          BMW     535i       23.7       36.2        22           30
# ..  ..          ...      ...        ...        ...       ...          ...
# 88  89   Volkswagen  Eurovan       16.6       22.7        17           21
# 89  90   Volkswagen   Passat       17.6       22.4        21           30
# 90  91   Volkswagen  Corrado       22.9       23.7        18           25
# 91  92        Volvo      240       21.8       23.5        21           28
# 92  93        Volvo      850       24.8       28.5        20           28
#
#                AirBags DriveTrain Cylinders  ...  Passengers  Length  \
# ...

# %% [markdown]
# # Preprocessing
# Standardisation

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
Xcon=pd.DataFrame(ss.fit_transform(Xcon),columns=con)

# %%
Xcon
# Out:
#           id  Min.Price  Max.Price  MPG.city  MPG.highway       RPM  \
# 0  -1.713526  -0.485787  -0.282465  0.471312     0.360925  1.717489
# 1  -1.676275   1.388017   1.531409 -0.781032    -0.770514  0.369586
# 2  -1.639025   1.008658   0.948052 -0.423219    -0.581941  0.369586
# 3  -1.601774   1.571949   2.069191 -0.602126    -0.581941  0.369586
# 4  -1.564523   0.755752   1.303535 -0.065407     0.172352  0.706562
# ..       ...        ...        ...       ...          ...       ...
# 88  1.564523  -0.060445   0.073018 -0.959938    -1.524806 -1.315292
# 89  1.601774   0.054512   0.045673 -0.244313     0.172352  0.875050
# 90  1.639025   0.663786   0.164167 -0.781032    -0.770514  0.875050
# 91  1.676275   0.537333   0.145937 -0.244313    -0.204794  0.201098
# 92  1.713526   0.882205   0.601684 -0.423219    -0.204794  1.549001
#
#     Rev.per.mile  Fuel.tank.capacity  Passengers    Length  Wheelbase  \
# 0       1.129530           -1.062184   -0.083243 -0.427186  -0.286932
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in Xcat.columns:
    Xcat[i]=le.fit_transform(Xcat[i])
# Out:
# C:\Users\waghm\AppData\Local\Temp\ipykernel_20660\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\waghm\AppData\Local\Temp\ipykernel_20660\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Xcat[i]=le.fit_transform(Xcat[i])
# C:\Users\waghm\AppData\Local\Temp\ipykernel_20660\188807692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
Xcat
# Out:
#     Manufacturer  Model  AirBags  DriveTrain  Cylinders  Man.trans.avail  \
# 0              0     48        1           1          1                1
# 1              0     55        0           1          3                1
# 2              1      8        1           1          3                1
# 3              1      0        1           1          3                1
# 4              2      5        1           2          1                1
# ..           ...    ...      ...         ...        ...              ...
# 88            30     41        1           1          2                1
# 89            30     64        1           1          1                1
# 90            30     28        1           1          3                1
# 91            31      2        1           2          1                1
# 92            31      7        0           1          2                1
#
#     Origin  Make
# 0        1     0
# 1        1     1
# 2        1     3
# 3        1     2
# ...

# %%
X=Xcon.join(Xcat)

# %%
X
# Out:
#           id  Min.Price  Max.Price  MPG.city  MPG.highway       RPM  \
# 0  -1.713526  -0.485787  -0.282465  0.471312     0.360925  1.717489
# 1  -1.676275   1.388017   1.531409 -0.781032    -0.770514  0.369586
# 2  -1.639025   1.008658   0.948052 -0.423219    -0.581941  0.369586
# 3  -1.601774   1.571949   2.069191 -0.602126    -0.581941  0.369586
# 4  -1.564523   0.755752   1.303535 -0.065407     0.172352  0.706562
# ..       ...        ...        ...       ...          ...       ...
# 88  1.564523  -0.060445   0.073018 -0.959938    -1.524806 -1.315292
# 89  1.601774   0.054512   0.045673 -0.244313     0.172352  0.875050
# 90  1.639025   0.663786   0.164167 -0.781032    -0.770514  0.875050
# 91  1.676275   0.537333   0.145937 -0.244313    -0.204794  0.201098
# 92  1.713526   0.882205   0.601684 -0.423219    -0.204794  1.549001
#
#     Rev.per.mile  Fuel.tank.capacity  Passengers    Length  ...  Luggage.room  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,Y,test_size=0.2,random_state=21)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
model=lr.fit(xtrain,ytrain)
# Out:
# C:\Users\waghm\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\waghm\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
tr_pred=model.predict(xtrain)

# %%
ts_pred=model.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
tr_score=accuracy_score(ytrain,tr_pred)

# %%
ts_score=accuracy_score(ytest,ts_pred)

# %%
print(tr_score)
# Out:
# 0.972972972972973

# %%
print(ts_score)
# Out:
# 1.0
